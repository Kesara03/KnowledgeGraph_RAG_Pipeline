# %% [markdown]
# ## Knowledge Graph (History of Greenland, Norway & Denmark)

# %% [markdown]
# **RAG Pipeline with Neo4j and Langchain**

# %%
# %pip install --upgrade --quiet  langchain langchain-community langchain-openai langchain-experimental wikipedia

# %%
# %pip install --upgrade --quiet  langchain langchain-community langchain-openai langchain-experimental neo4j wikipedia tiktoken yfiles_jupyter_graphs

# %%
# !pip install --quiet langchain-neo4j

# %%
import os

# %%
from google.colab import userdata
OPENAI_API_KEY=userdata.get('OPENAI_API_KEY')

# %%
NEO4J_URI="neo4j+s://b79f9be3.databases.neo4j.io"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="F-SLmj1h4qsnhshI_2ImfzsDK597qkxjO9A2E83cluM"

# %%
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
os.environ["NEO4J_URI"] = NEO4J_URI
os.environ["NEO4J_USERNAME"] = NEO4J_USERNAME
os.environ["NEO4J_PASSWORD"] = NEO4J_PASSWORD

# %%
from langchain_community.graphs import Neo4jGraph

# %%
graph = Neo4jGraph()
# Out:
# /tmp/ipython-input-267675202.py:1: LangChainDeprecationWarning: The class `Neo4jGraph` was deprecated in LangChain 0.3.8 and will be removed in 1.0. An updated version of the class exists in the `langchain-neo4j package and should be used instead. To use it run `pip install -U `langchain-neo4j` and import as `from `langchain_neo4j import Neo4jGraph``.
#   graph = Neo4jGraph()

# %%
from langchain_community.document_loaders import WikipediaLoader

topics = [
    "History of Greenland",
    "History of Norway",
    "History of Denmark"
]



raw_documents = []
for topic in topics:
    docs = WikipediaLoader(query=topic).load()
    raw_documents.extend(docs)

print(f"Loaded {len(raw_documents)} documents")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Loaded 75 documents

# %%
raw_documents
# Out:
# [Document(metadata={'title': 'History of Greenland', 'summary': 'The history of Greenland is a history of life under extreme Arctic conditions: currently, an ice sheet covers about eighty percent of the island, restricting human activity largely to the coasts. The first humans are thought to have arrived in Greenland around 2500 BCE. Their descendants most likely died out and were replaced and succeeded by several other human groups migrating from continental North America since then. There has been no evidence discovered that Greenland was known to Norsemen until the 9th century CE, when Norse Icelandic explorers settled on its southwestern coast. The ancestors of the Greenlandic Inuit who live there today appear to have migrated there later, around the year 1200, across the Nares Strait from northern Canada.\nWhile Inuit survived in the icy world of the Little Ice Age, the early Norse settlements, known as the Eastern Settlement, along the southwestern coast disappeared, leaving Inuit as the only inhabitants of the island for several centuries. During this time, Denmark–Norway, apparently believing the Norse settlements had survived, continued to claim sovereignty over the island despite the lack of any contact between the Norsemen (specifically Icelanders) installed in Greenland and their Scandinavian brethren. In 1721, aspiring to become a colonial power, Denmark-Norway sent a missionary expedition to Greenland with the stated aim of reinstating Christianity among descendants of the Norse Greenlanders who may have converted back to paganism. When the missionaries found no descendants of the Norse Greenlanders, they baptised the Inuit they found living there instead. Denmark-Norway then developed trading colonies along the coast and imposed a trade monopoly and other colonial privileges on the area.\nDuring World War II, when Nazi Germany invaded Denmark, Greenlanders became socially and economically less connected to Denmark and more, though informally, connected to the United States. It has never been a US territory. After the war, Denmark resumed control of Greenland and in 1953, converted its status from colony to overseas amt (county). Although Greenland is still a part of the Danish Realm, it has enjoyed home rule since
states have been somewhat intertwined: The former Israeli minister of social and diaspora affairs Michael Melchior was born in Denmark and is the son of former chief rabbi in Copenhagen, Bent Melchior, the nephew of former Danish minister of traffic and minister of tourism and communication Arne Melchior, and the grandson of the acting rabbi for the Jewish refugees from Denmark in Sweden 1943–45, Marcus Melchior; the executive director of the Peres Center for Peace 2001–2011, Ron Pundak, who played an important role in starting the Oslo peace process and was part of the core group behind the Geneva Initiative, is the son of the influential Danish journalist Herbert Pundik; and prominent Israeli politician Yohanan Plesner, former chairman of the Plesner Committee, is the son of Danish architect Ulrik Plesner.\n\n\n== Historical visits ==\nIn January 1962, Viggo Kampma ...

# %%
len(raw_documents)
# Out:
# 75

# %%
from langchain_text_splitters import TokenTextSplitter
text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=24)
documents = text_splitter.split_documents(raw_documents)
print(f"Total chunks: {len(documents)}")
# Out:
# Total chunks: 145

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-0125")

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
llm_transformer = LLMGraphTransformer(llm=llm)
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_openai/chat_models/base.py:2073: UserWarning: Cannot use method='json_schema' with model gpt-3.5-turbo-0125 since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(

# %%
graph_documents = llm_transformer.convert_to_graph_documents(documents)

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Greenland', type='Location', properties={}), Node(id='Ice Sheet', type='Natural feature', properties={}), Node(id='Humans', type='Species', properties={}), Node(id='Coasts', type='Location', properties={}), Node(id='First Humans', type='Species', properties={}), Node(id='Descendants', type='Species', properties={}), Node(id='Human Groups', type='Species', properties={}), Node(id='Continental North America', type='Location', properties={}), Node(id='Norsemen', type='Ethnic group', properties={}), Node(id='Norse Icelandic Explorers', type='Ethnic group', properties={}), Node(id='Greenlandic Inuit', type='Ethnic group', properties={}), Node(id='Nares Strait', type='Location', properties={}), Node(id='Canada', type='Location', properties={}), Node(id='Inuit', type='Ethnic group', properties={}), Node(id='Little Ice Age', type='Event', properties={}), Node(id='Eastern Settlement', type='Location', properties={}), Node(id='Denmark–Norway', type='Country', properties={}), Node(id='Icelanders', type='Ethnic group', properties={}), Node(id='Denmark-Norway', type='Country', properties={}), Node(id='Christianity', type='Religion', properties={}), Node(id='Pagans', type='Religion', properties={}), Node(id='Missionary Expedition', type='Event', properties={}), Node(id='Trading Colonies', type='Location', properties={}), Node(id='Trade Monopoly', type='Concept', properties={}), Node(id='Colonial Privileges', type='Concept', properties={}), Node(id='Nazi Germany', type='Country', properties={}), Node(id='United States', type='Country', properties={}), Node(id='Us Territory', type='Location', properties={}), Node(id='World War Ii', type='Event', properties={}), Node(id='European Economic Community (Eec)', type='Organization', properties={}), Node(id='Danish Realm', type='Country', properties={}), Node(id='Home Rule', type='Concept', properties={}), Node(id='Overseas Amt (County)', type='Concept', properties={})], relationships=[Relationship(source=Node(id='Greenland', type='Location', properties={}), target=Node(id='Ice Sheet', type='Natural feature', properties={}), type='COVERS', properties={}), Relationship(source=Node(id='Greenland', type='Location', properties={}), target=Node(id='Coasts', type='Location', properties={}), type='RESTRICTS_HUMAN_ACTIVITY_TO', properties={}), Relationship(source=Node(id='First Humans', type='Species', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='ARRIVED_IN', properties={}), Relationship(source=Node(id='First Humans', type='Species', properties={}), target=Node(id='Continental North America', type='Location', properties={}), type='MIGRATED_FROM', properties={}), Relationship(source=Node(id='Norsemen', type='Ethnic group', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='DISCOVERED_GREENLAND_IN', properties={}), Relationship(source=Node(id='Norse Icelandic Explorers', type='Ethnic group', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='SETTLED_ON', properties={}), Relationship(source=Node(id='Greenlandic Inuit', type='Ethnic group', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='MIGRATED_TO', properties={}), Relationship(source=Node(id='Greenlandic Inuit', type='Ethnic group', properties={}), target=Node(id='Canada', type='Location', properties={}), type='MIGRATED_FROM', properties={}), Relationship(source=Node(id='Inuit', type='Ethnic group', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='SURVIVED_IN', properties={}), Relationship(source=Node(id='Eastern Settlement', type='Location', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='DISAPPEARED_FROM', properties={}), Relationship(source=Node(id='Denmark–Norway', type='Country', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='CLAIMED_SOVEREIGNTY_OVER', properties={}), Relationship(sourc ...
#  GraphDocument(nodes=[Node(id='Greenland', type='Place', properties={}), Node(id='Saqqaq Culture', type='Culture', properties={}), Node(id='Independence I Culture', type='Culture', properties={}), Node(id='Independence Ii Culture', type='Culture', properties={}), Node(id='Norse Exploration Of Greenland', type='Event', properties={}), Node(id='Dorset Culture', type='Culture', properties={}), Node(id='North America', type='Place', properties={}), Node(id='Nunavut', type='Place', properties={}), Node(id='Beringia', type='Place', properties={}), Node(id='Inglefield Land', type='Place', properties={})], relationships=[Relationship(source=Node(id='Greenland', type='Place', properties={}), target=Node(id='Saqqaq Culture', type='Culture', properties={}), type='EARLIEST_KNOWN_CULTURE', properties={}), Relationship(source=Node(id='Greenland', type='Place', properties={}), target=Node(id='Independence I Culture', type='Culture', properties={}), type='EARLIEST_KNOWN_CULTURE', properties={}), Relationship(source=Node(id='Greenland', type='Place', properties={}), target=Node(id='Independence Ii Culture', type='Culture', properties={}), type='CULTURE', properties={}), Relationship(source=Node(id='Greenland', type='Place', properties={}), target=Node(id='Norse Exploration Of Greenland', type='Event', properties={}), type='EVENT', properties={}), Relationship(source=Node(id='Greenland', type='Place', properties={}), target=Node(id='Dorset Culture', type='Culture', properties={}), type='CULTURE', properties={}), Relationship(source=Node(id='North America', type='Place', properties={}), target=Node(id='Greenland', type='Place', properties={}), type='MIGRATION_SOURCE', properties={}), Relationship(source=Node(id='Nunavut', type='Place', properties={}), target=Node(id='Greenland', type='Place', properties={}), type='MIGRATION_SOURCE', properties={}), Relationship(source=Node(id='Beringia', type='Place', properties={}), target=Node(id='North America', type='Place', properties={}), type='MIGRATION_SOURCE', properties={}), Relationship(source=Node(id='Inglefield Land', type='Place', properties={}), target=Node(id='Greenland', type='Place', properties={}), type='ARTIFACT_LOCATION', properties={})], source=Document(metadata={'title': 'History of Greenland', 'summary': 'The history of Greenland is a history of life under extreme Arctic conditions: currently, an ice sheet covers about eighty percent of the island, restricting human activity largely to the coasts. The first humans are thought to have arrived in Greenland around 2500 BCE. Their descendants most likely died out and were replaced and succeeded by several other human groups migrating from continental North America since then. There has been no evidence discovered that Greenland was known to Norsemen until the 9th century CE, when Norse Icelandic explorers settled on its southwestern coast. The ancestors of the Greenlandic Inuit who live there today appear to have migrated there later, around the year 1200, across the Nares Strait from northern Canada.\nWhile Inuit survived in the icy world of the Little Ice Age, the early Norse settlements, known as the Eastern Settlement, along the southwestern coast disappeared, leaving Inuit as the only inhabitants of the island for several centuries. During this time, Denmark–Norway, apparently believing the Norse settlements had survived, continued to claim sovereignty over the island despite the lack of any contact between the Norsemen (specifically Icelanders) installed in Greenland and their Scandinavian brethren. In 1721, aspiring to become a colonial power, Denmark-Norway sent a missionary expedition to Greenland with the stated aim of reinstating Christianity among descendants of the Norse Greenlanders who may have converted back to paganism. When the missionaries found no descendants of the Norse Greenlanders, they baptised the Inuit they found living there instead. Denmark-Norway then developed trading colonies along the coast and imposed a trade ...
#  GraphDocument(nodes=[Node(id='Denmark', type='Country', properties={}), Node(id='Greenland', type='Territory', properties={}), Node(id='United Kingdom', type='Country', properties={}), Node(id='United States', type='Country', properties={}), Node(id='Canada', type='Country', properties={}), Node(id='Dominion', type='Territory', properties={}), Node(id='British Empire', type='Territory', properties={}), Node(id='Coast Guard', type='Organization', properties={}), Node(id='Portugal', type='Country', properties={}), Node(id='Monroe Doctrine', type='Concept', properties={}), Node(id='Nazi Germany', type='Country', properties={}), Node(id='Eske Brun', type='Person', properties={}), Node(id='Aksel Svane', type='Person', properties={}), Node(id='Henrik Kauffmann', type='Person', properties={}), Node(id='State Department', type='Organization', properties={}), Node(id='Landsraad', type='Organization', properties={})], relationships=[Relationship(source=Node(id='Denmark', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='CONTROLLED', properties={}), Relationship(source=Node(id='Denmark', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='OCCUPIED', properties={}), Relationship(source=Node(id='Denmark', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='FALLEN', properties={}), Relationship(source=Node(id='Greenland', type='Territory', properties={}), target=Node(id='United Kingdom', type='Country', properties={}), type='POSSIBILITY_OF_SEIZURE', properties={}), Relationship(source=Node(id='Greenland', type='Territory', properties={}), target=Node(id='United States', type='Country', properties={}), type='POSSIBILITY_OF_SEIZURE', properties={}), Relationship(source=Node(id='Greenland', type='Territory', properties={}), target=Node(id='Canada', type='Country', properties={}), type='POSSIBILITY_OF_SEIZURE', properties={}), Relationship(source=Node(id='Greenland', type='Territory', properties={}), target=Node(id='Dominion', type='Territory', properties={}), type='POSSIBILITY_OF_SEIZURE', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ESTABLISHED_FACILITIES', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ESTABLISHED_TRAFFIC_FACILITIES', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ESTABLISHED_RADIO_BEACONS', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ESTABLISHED_RADIO_STATIONS', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ESTABLISHED_WEATHER_STATIONS', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ESTABLISHED_PORTS', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ESTABLISHED_DEPOTS', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ESTABLISHED_ARTILLERY_POSTS', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ESTABLISHED_SEARCH-AND-RESCUE_STATIONS', properties={}), Relationship(source=Node(id='Coast Guard', type='Organization', properties={}), target=Node(id='United States', type='Coun ...
#  GraphDocument(nodes=[Node(id='Sheriffs', type='Person', properties={}), Node(id='Landsraad', type='Organization', properties={}), Node(id='Danish Government', type='Organization', properties={}), Node(id='Portugal', type='Country', properties={}), Node(id='Greenlanders', type='Person', properties={}), Node(id='Dominion Of Canada', type='Country', properties={}), Node(id='Free Norwegian Forces', type='Organization', properties={}), Node(id='Permanent Court Of International Justice', type='Organization', properties={}), Node(id='United States', type='Country', properties={}), Node(id='Treasury Department', type='Organization', properties={}), Node(id='U.S. Coast Guard', type='Organization', properties={}), Node(id='Uscgc Comanche', type='Organization', properties={}), Node(id='Uscgc Campbell', type='Organization', properties={}), Node(id='Consulate', type='Organization', properties={}), Node(id='Canada', type='Country', properties={})], relationships=[Relationship(source=Node(id='Sheriffs', type='Person', properties={}), target=Node(id='Landsraad', type='Organization', properties={}), type='INFORMED', properties={}), Relationship(source=Node(id='Danish Government', type='Organization', properties={}), target=Node(id='Portugal', type='Country', properties={}), type='COMMUNICATED', properties={}), Relationship(source=Node(id='Greenlanders', type='Person', properties={}), target=Node(id='Dominion Of Canada', type='Country', properties={}), type='WORRIED_ABOUT', properties={}), Relationship(source=Node(id='Dominion Of Canada', type='Country', properties={}), target=Node(id='Free Norwegian Forces', type='Organization', properties={}), type='ATTEMPTED_OCCUPATION', properties={}), Relationship(source=Node(id='Norwegians', type='Person', properties={}), target=Node(id='Permanent Court Of International Justice', type='Organization', properties={}), type='DISPUTE_SETTLED', properties={}), Relationship(source=Node(id='Greenlanders', type='Person', properties={}), target=Node(id='United States', type='Country', properties={}), type='REQUESTED_PROTECTION', properties={}), Relationship(source=Node(id='Treasury Department', type='Organization', properties={}), target=Node(id='Uscgc Comanche', type='Organization', properties={}), type='DISPATCHED', properties={}), Relationship(source=Node(id='Treasury Department', type='Organization', properties={}), target=Node(id='Uscgc Campbell', type='Organization', properties={}), type='DISPATCHED', properties={}), Relationship(source=Node(id='Uscgc Comanche', type='Organization', properties={}), target=Node(id='Consulate', type='Organization', properties={}), type='ESTABLISHED', properties={}), Relationship(source=Node(id='Canada', type='Country', properties={}), target=Node(id='Consulate', type='Organization', properties={}), type='SENT', properties={})], source=Document(metadata={'title': 'Greenland in World War II', 'summary': "The fall of Denmark in April 1940 left the Danish colony of Greenland an unoccupied territory of an occupied nation, under the possibility of seizure by the United Kingdom, United States or Canada, a Dominion of the British Empire.\nFrom 1941 until 1945, the United States established numerous and extensive facilities for air and sea traffic in Greenland, as well as radio beacons, radio stations, weather stations, ports, depots, artillery posts, and search-and-rescue stations. The United States Coast Guard also provided a considerable portion of civilian resupply along both coasts.\nEconomically, Greenland traded successfully with the United States, Canada and Portugal, which, supplemented by the cryolite exports, caused a reanimation and permanent realignment of the island's economy.", 'source': 'https://en.wikipedia.org/wiki/Greenland_in_World_War_II'}, page_content=' sheriffs informed the local advisory parliament ("Landsraad") on 3 May that "there was no choice" but to act as a sovereign nation. The Danish Government continued to send orders to the colony via radio and throu ...
#  GraphDocument(nodes=[Node(id='United States', type='Country', properties={}), Node(id='Greenland', type='Territory', properties={}), Node(id='Denmark', type='Country', properties={}), Node(id='Alaska', type='Territory', properties={}), Node(id='Louisiana Purchase', type='Territory', properties={}), Node(id='Nato', type='Organization', properties={}), Node(id='William H. Seward', type='Person', properties={}), Node(id='World War Ii', type='Event', properties={}), Node(id='Joint Chiefs Of Staff', type='Organization', properties={}), Node(id='Donald Trump', type='Person', properties={}), Node(id='Mette Frederiksen', type='Person', properties={}), Node(id='Monroe Doctrine', type='Doctrine', properties={}), Node(id='Germany', type='Country', properties={}), Node(id='Thule Air Base', type='Military base', properties={}), Node(id='Pituffik Space Base', type='Military base', properties={})], relationships=[Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='DESIRE_TO_OBTAIN', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Alaska', type='Territory', properties={}), type='ACQUISITION', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Louisiana Purchase', type='Territory', properties={}), type='ACQUISITION', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Denmark', type='Country', properties={}), type='ATTEMPTED_PURCHASE', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='MILITARY_BASES_ESTABLISHMENT', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='SECRET_OFFER_TO_BUY', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='THREAT_TO_INVADE_OR_ANNEX', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='HISTORICAL_STRATEGIC_IMPORTANCE', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='OCCUPATION_TO_PREVENT_USE_BY_GERMANY', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='PARTICIPATION_IN_NATO_EXERCISES', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='WARNING_TO_LEAVE_BASES', properties={}), Relationship(source=Node(id='William H. Seward', type='Person', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ADVOCACY_FOR_PURCHASE', properties={}), Relationship(source=Node(id='Joint Chiefs Of Staff', type='Organization', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='PROPOSAL_TO_ACQUIRE', properties={}), Relationship(source=Node(id='Donald Trump', type='Person', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ADVOCACY_FOR_ACQUISITION', properties={}), Relationship(source=Node(id='Donald Trump', type='Person', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='THREAT_TO_INVADE_OR_ANNEX', properties={}), Relationship(source=Node(id='Donald Trump', type='Person', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='ASSERTION_OF_AMERICAN_EXPANSIONISM', properties={}), Relationship(source=Node(id='Mette Frederiksen', type='Person', properties={}),  ...
#  GraphDocument(nodes=[Node(id='Greenland', type='Location', properties={}), Node(id='Us', type='Country', properties={}), Node(id='Nato', type='Organization', properties={}), Node(id='Denmark', type='Country', properties={})], relationships=[Relationship(source=Node(id='Us', type='Country', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='PARTICIPATES_IN', properties={}), Relationship(source=Node(id='Us', type='Country', properties={}), target=Node(id='Nato', type='Organization', properties={}), type='PARTICIPATES_IN', properties={}), Relationship(source=Node(id='Us', type='Country', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='ANNEXATION_ENDS_NATO', properties={}), Relationship(source=Node(id='Greenland', type='Location', properties={}), target=Node(id='Denmark', type='Country', properties={}), type='AUTONOMOUS_TERRITORY', properties={})], source=Document(metadata={'title': 'Proposed United States acquisition of Greenland', 'summary': 'Since the 19th century, the United States has made several attempts to obtain the island of Greenland from Denmark. Historically, nearly 40% of the territory of the US was acquired through purchase; notably Alaska and the Louisiana purchase. There were discussions within the US federal government about purchasing Greenland in 1867, advocated by secretary of state William H. Seward, and again in 1910. During World War II, the US built military bases in Greenland, and since then it has had at least one military base there. In 1946, the US secretly offered to buy Greenland, but it was rejected by Denmark. Since 1949, Greenland has been under the protection of NATO, of which the US and Denmark are both members. Nevertheless, the Joint Chiefs of Staff proposed acquiring Greenland in 1955. More recently, Donald Trump has asserted during his two presidencies that the US should take over Greenland.\nIn 2019, during his first presidency, Donald Trump expressed his desire for the US to purchase Greenland; it was turned down and described as "absurd" by Danish Prime Minister Mette Frederiksen. During his second presidency, since 2025, Trump has advocated American expansionism and has increasingly asserted that the US must acquire Greenland. Following Greenlandic and Danish refusals to sell the country, Trump has threatened to invade or annex Greenland, which would break international law. This triggered the Greenland crisis. \nGreenland is an autonomous territory within the Kingdom of Denmark. Greenlandic and Danish authorities have publicly asserted Greenland\'s right to self-determination and stated that Greenland is "not for sale". Most Greenlanders oppose an American takeover, and many Danes see the historical ties with Greenland as an integral part of Danish national identity.\nThe US has long seen Greenland as vital for the defense of its mainland, and former war plans listed Greenland as one of the territories the US would seize and fortify to defend itself in a hypothetical war. During World War II, the US invoked its Monroe Doctrine and occupied Greenland to prevent use by Germany following the German occupation of Denmark. The US military remained in Greenland after the war, and by 1948, Denmark abandoned attempts to persuade the US to leave. The following year, both countries became NATO members. A 1951 treaty gave the US a significant role in Greenland\'s defense and allowed it to have bases there. The US eventually shut all of its bases except for Thule air base, now Pituffik Space Base, in northwest Greenland. While the US military often takes part in NATO exercises in Greenlandic waters, it has been warned that a US annexation of Greenland would effectively end NATO.', 'source': 'https://en.wikipedia.org/wiki/Proposed_United_States_acquisition_of_Greenland'}, page_content=", in northwest Greenland. While the US military often takes part in NATO exercises in Greenlandic waters, it has been warned that a US annexation of  ...
#  GraphDocument(nodes=[Node(id='Nuuk', type='City', properties={}), Node(id='Greenland', type='Territory', properties={}), Node(id='Kingdom Of Denmark', type='Kingdom', properties={}), Node(id='Sermersooq Municipality', type='Government', properties={}), Node(id='Hans Egede', type='Missionary', properties={}), Node(id='Claus Paarss', type='Governor', properties={}), Node(id='Hope Colony', type='Settlement', properties={}), Node(id='Inuit', type='Ethnic group', properties={}), Node(id='Nûk', type='Settlement', properties={}), Node(id='Nuup Kangerlua Fjord', type='Landmark', properties={}), Node(id='Labrador Sea', type='Sea', properties={}), Node(id='Reykjavík', type='City', properties={}), Node(id='Saqqaq Culture', type='Culture', properties={}), Node(id='Qoornoq', type='Settlement', properties={}), Node(id='Dorset Culture', type='Culture', properties={}), Node(id='Kangeq', type='Settlement', properties={}), Node(id='Norse Settlers', type='Settlers', properties={})], relationships=[Relationship(source=Node(id='Nuuk', type='City', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='LOCATED_IN', properties={}), Relationship(source=Node(id='Nuuk', type='City', properties={}), target=Node(id='Kingdom Of Denmark', type='Kingdom', properties={}), type='PART_OF', properties={}), Relationship(source=Node(id='Nuuk', type='City', properties={}), target=Node(id='Sermersooq Municipality', type='Government', properties={}), type='SEAT_OF_GOVERNMENT', properties={}), Relationship(source=Node(id='Hans Egede', type='Missionary', properties={}), target=Node(id='Nuuk', type='City', properties={}), type='FOUNDED', properties={}), Relationship(source=Node(id='Claus Paarss', type='Governor', properties={}), target=Node(id='Nuuk', type='City', properties={}), type='FOUNDED', properties={}), Relationship(source=Node(id='Hope Colony', type='Settlement', properties={}), target=Node(id='Nuuk', type='City', properties={}), type='RELOCATED_TO', properties={}), Relationship(source=Node(id='Nûk', type='Settlement', properties={}), target=Node(id='Nuuk', type='City', properties={}), type='ORIGINAL_NAME', properties={}), Relationship(source=Node(id='Nuuk', type='City', properties={}), target=Node(id='Nuup Kangerlua Fjord', type='Landmark', properties={}), type='LOCATED_AT', properties={}), Relationship(source=Node(id='Nuup Kangerlua Fjord', type='Landmark', properties={}), target=Node(id='Labrador Sea', type='Sea', properties={}), type='NEAR', properties={}), Relationship(source=Node(id='Nuuk', type='City', properties={}), target=Node(id='Reykjavík', type='City', properties={}), type='NORTHERNMOST_CAPITAL', properties={}), Relationship(source=Node(id='Saqqaq Culture', type='Culture', properties={}), target=Node(id='Nuuk', type='City', properties={}), type='FIRST_OCCUPANTS', properties={}), Relationship(source=Node(id='Qoornoq', type='Settlement', properties={}), target=Node(id='Nuuk', type='City', properties={}), type='FORMER_SETTLEMENT', properties={}), Relationship(source=Node(id='Dorset Culture', type='Culture', properties={}), target=Node(id='Nuuk', type='City', properties={}), type='OCCUPIED_BY', properties={}), Relationship(source=Node(id='Kangeq', type='Settlement', properties={}), target=Node(id='Nuuk', type='City', properties={}), type='FORMER_SETTLEMENT', properties={}), Relationship(source=Node(id='Norse Settlers', type='Settlers', properties={}), target=Node(id='Nuuk', type='City', properties={}), type='INHABITED_BY', properties={})], source=Document(metadata={'title': 'Nuuk', 'summary': 'Nuuk (Greenlandic pronunciation: [nuːk] ; Danish: Nuuk, formerly Godthåb [ˈkʌtˌhɔˀp]) is the capital and most populous city of Greenland, a rigsdel (an autonomous territory) in the Kingdom of Denmark. Nuuk is the seat of government and the territory\'s largest cultural and economic center. It is also the seat of government for the Sermersooq municipality. In January 2025, it had a population of 20,113—more than a third of the territ ...
#  GraphDocument(nodes=[Node(id='Haab', type='Colony', properties={}), Node(id='Claus Paarss', type='Governor', properties={}), Node(id='Hans Egede', type='Missionary', properties={}), Node(id='Hope Colony', type='Colony', properties={}), Node(id='Kangeq Island', type='Island', properties={}), Node(id='Greenland', type='Colony', properties={}), Node(id='Norwegian Crown', type='Crown', properties={}), Node(id="Paarss'S Colonists", type='Colonists', properties={}), Node(id='Soldiers', type='Occupation', properties={}), Node(id='Convicts', type='Occupation', properties={}), Node(id='Prostitutes', type='Occupation', properties={}), Node(id='Scurvy', type='Ailment', properties={}), Node(id='Smallpox', type='Epidemic', properties={}), Node(id='Native Population', type='Population', properties={}), Node(id='Godthaab', type='Government seat', properties={}), Node(id='South Greenland', type='Region', properties={}), Node(id='Godhavn', type='Capital', properties={}), Node(id='Qeqertarsuaq', type='City', properties={}), Node(id='Denmark', type='Country', properties={}), Node(id='Moravian Missionaries', type='Missionaries', properties={}), Node(id='New Herrnhut', type='Mission house', properties={}), Node(id='Nuuk', type='City', properties={}), Node(id='Greenlanders', type='People', properties={}), Node(id='Southeastern Coast', type='Region', properties={}), Node(id='Lichtenfels', type='Mission', properties={}), Node(id='Lichtenau', type='Mission', properties={}), Node(id='Friedrichsthal', type='Mission', properties={}), Node(id='Umanak', type='Mission', properties={}), Node(id='Idlorpait', type='Mission', properties={}), Node(id='Lutheran Church Of Denmark', type='Church', properties={}), Node(id='Hinrich Johannes Rink', type='Person', properties={}), Node(id='Atuagagdliutit', type='Newspaper', properties={}), Node(id='World War Ii', type='Event', properties={})], relationships=[Relationship(source=Node(id='Claus Paarss', type='Governor', properties={}), target=Node(id='Haab', type='Colony', properties={}), type='FOUNDED', properties={}), Relationship(source=Node(id='Claus Paarss', type='Governor', properties={}), target=Node(id='Hans Egede', type='Missionary', properties={}), type='RELOCATED', properties={}), Relationship(source=Node(id='Claus Paarss', type='Governor', properties={}), target=Node(id='Hope Colony', type='Colony', properties={}), type='RELOCATED', properties={}), Relationship(source=Node(id='Claus Paarss', type='Governor', properties={}), target=Node(id='Kangeq Island', type='Island', properties={}), type='FROM', properties={}), Relationship(source=Node(id='Claus Paarss', type='Governor', properties={}), target=Node(id='Greenland', type='Colony', properties={}), type='UNDER', properties={}), Relationship(source=Node(id="Paarss'S Colonists", type='Colonists', properties={}), target=Node(id='Scurvy', type='Ailment', properties={}), type='DIED_OF', properties={}), Relationship(source=Node(id="Paarss'S Colonists", type='Colonists', properties={}), target=Node(id='Smallpox', type='Epidemic', properties={}), type='DIED_OF', properties={}), Relationship(source=Node(id='Hans Egede', type='Missionary', properties={}), target=Node(id='Denmark', type='Country', properties={}), type='RETURNED_TO', properties={}), Relationship(source=Node(id='Hans Egede', type='Missionary', properties={}), target=Node(id='Greenland', type='Colony', properties={}), type='WORKED_IN', properties={}), Relationship(source=Node(id='Hans Egede', type='Missionary', properties={}), target=Node(id='Poul', type='Person', properties={}), type='LEFT_IN_CHARGE', properties={}), Relationship(source=Node(id='Hans Egede', type='Missionary', properties={}), target=Node(id='Godthaab', type='Government seat', properties={}), type='ESTABLISHED', properties={}), Relationship(source=Node(id='Godhavn', type='Capital', properties={}), target=Node(id='North Greenland', type='Region', properties={}), type='CAPITAL_OF', properties={}), Relationship(source=Node(id='North Greenland' ...
#  GraphDocument(nodes=[Node(id='Greenland', type='Island', properties={}), Node(id='Vilhjálmur Örn Vilhjálmsson', type='Person', properties={}), Node(id='Alfred Wegener', type='Person', properties={}), Node(id='Fritz Loewe', type='Person', properties={}), Node(id='Henrik Kauffmann', type='Person', properties={}), Node(id='Julius Amos Leibert', type='Person', properties={}), Node(id='Harold Gordon', type='Person', properties={}), Node(id='Jeshaia Schnitzer', type='Person', properties={}), Node(id='Albert A. Goldman', type='Person', properties={}), Node(id='Israel Miller', type='Person', properties={})], relationships=[Relationship(source=Node(id='Greenland', type='Island', properties={}), target=Node(id='Vilhjálmur Örn Vilhjálmsson', type='Person', properties={}), type='HISTORIAN', properties={}), Relationship(source=Node(id='Greenland', type='Island', properties={}), target=Node(id='Alfred Wegener', type='Person', properties={}), type='METEOROLOGIST', properties={}), Relationship(source=Node(id='Alfred Wegener', type='Person', properties={}), target=Node(id='Fritz Loewe', type='Person', properties={}), type='FRIEND', properties={}), Relationship(source=Node(id='Denmark', type='Country', properties={}), target=Node(id='Henrik Kauffmann', type='Person', properties={}), type='AMBASSADOR', properties={}), Relationship(source=Node(id='Greenland', type='Island', properties={}), target=Node(id='Julius Amos Leibert', type='Person', properties={}), type='ARMY_CHAPLAIN', properties={}), Relationship(source=Node(id='Greenland', type='Island', properties={}), target=Node(id='Harold Gordon', type='Person', properties={}), type='RABBI', properties={}), Relationship(source=Node(id='Greenland', type='Island', properties={}), target=Node(id='Jeshaia Schnitzer', type='Person', properties={}), type='RABBI', properties={}), Relationship(source=Node(id='Greenland', type='Island', properties={}), target=Node(id='Albert A. Goldman', type='Person', properties={}), type='RABBI', properties={}), Relationship(source=Node(id='Greenland', type='Island', properties={}), target=Node(id='Israel Miller', type='Person', properties={}), type='RABBI', properties={})], source=Document(metadata={'title': 'History of the Jews in Greenland', 'summary': 'Greenland is a large, mostly arctic, and ice-covered Island, in the Western Hemisphere, with a population of 56,789 people as of 2024. There is only one Jew on the island, though there have also been Jews who have lived there temporarily, like Danish Jewish soldiers, American Jewish soldiers, Israeli Navy members, and members of the Israeli Air Force.', 'source': 'https://en.wikipedia.org/wiki/History_of_the_Jews_in_Greenland'}, page_content='Greenland is a large, mostly arctic, and ice-covered Island, in the Western Hemisphere, with a population of 56,789 people as of 2024. There is only one Jew on the island, though there have also been Jews who have lived there temporarily, like Danish Jewish soldiers, American Jewish soldiers, Israeli Navy members, and members of the Israeli Air Force.\n\n\n== History ==\nBefore 2001, there had never been a permanent Jewish community in Greenland, though Jewish fishermen were known to frequent the island\'s waters.\n\n\n=== Early modern period (16th to 17th centuries) ===\nIcelandic-born historian Vilhjálmur Örn Vilhjálmsson writes in his book Antisemitism in the North that "there were certainly Jews among the first Dutch whalers in the 16th and 17th centuries."\n\n\n=== Late modern period (20th century) ===\nIn the 1920s, Alfred Wegener, who famously discovered continental drift, came to Greenland with his friend and fellow meteorologist Fritz Loewe, who was Jewish. Loewe got frostbite while trying to reach the center of Greenland. Loewe\'s team had to amputate his toes with scissors.\nAfter the German occupation of Denmark on 9 April 1940, Henrik Kauffmann, Danish Ambassador to the United States, made an agreement "In the name of the king" with the United States, authorizing the ...
#  GraphDocument(nodes=[Node(id='Jewish High Holidays', type='Event', properties={}), Node(id='Vilhjálmsson', type='Person', properties={}), Node(id='Thule', type='Location', properties={}), Node(id='Alfred J. Fischer', type='Person', properties={}), Node(id='Aasiaat', type='Location', properties={}), Node(id='Rita Scheftelowitz', type='Person', properties={}), Node(id='Denmark', type='Location', properties={}), Node(id='Sweden', type='Location', properties={}), Node(id='Greenland', type='Location', properties={}), Node(id='Contemporary Era', type='Time period', properties={}), Node(id='Pituffik Space Base', type='Location', properties={}), Node(id='Paul Cohen', type='Person', properties={}), Node(id='Narsaq', type='Location', properties={}), Node(id='Monika', type='Person', properties={})], relationships=[Relationship(source=Node(id='Jewish High Holidays', type='Event', properties={}), target=Node(id='Thule', type='Location', properties={}), type='OCCURRED_AT', properties={}), Relationship(source=Node(id='Vilhjálmsson', type='Person', properties={}), target=Node(id='Thule', type='Location', properties={}), type='MENTIONED', properties={}), Relationship(source=Node(id='Alfred J. Fischer', type='Person', properties={}), target=Node(id='Aasiaat', type='Location', properties={}), type='VISITED', properties={}), Relationship(source=Node(id='Alfred J. Fischer', type='Person', properties={}), target=Node(id='Rita Scheftelowitz', type='Person', properties={}), type='MET', properties={}), Relationship(source=Node(id='Rita Scheftelowitz', type='Person', properties={}), target=Node(id='Denmark', type='Location', properties={}), type='ORIGINATED_FROM', properties={}), Relationship(source=Node(id='Rita Scheftelowitz', type='Person', properties={}), target=Node(id='Sweden', type='Location', properties={}), type='MOVED_TO', properties={}), Relationship(source=Node(id='Rita Scheftelowitz', type='Person', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='MOVED_TO', properties={}), Relationship(source=Node(id='Rita Scheftelowitz', type='Person', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='LIVED_AT', properties={}), Relationship(source=Node(id='Rita Scheftelowitz', type='Person', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='PRACTICED_RELIGION', properties={}), Relationship(source=Node(id='Rita Scheftelowitz', type='Person', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='ATE_KOSHER', properties={}), Relationship(source=Node(id='Contemporary Era', type='Time period', properties={}), target=Node(id='Pituffik Space Base', type='Location', properties={}), type='BEING_USED_AS_BASE', properties={}), Relationship(source=Node(id='Pituffik Space Base', type='Location', properties={}), target=Node(id='Greenland', type='Location', properties={}), type='RELOCATED_TO', properties={}), Relationship(source=Node(id='Paul Cohen', type='Person', properties={}), target=Node(id='Narsaq', type='Location', properties={}), type='LIVING_AT', properties={}), Relationship(source=Node(id='Paul Cohen', type='Person', properties={}), target=Node(id='Narsaq', type='Location', properties={}), type='WORKS_AT', properties={}), Relationship(source=Node(id='Paul Cohen', type='Person', properties={}), target=Node(id='Narsaq', type='Location', properties={}), type='JEWISH_RESIDENT', properties={}), Relationship(source=Node(id='Paul Cohen', type='Person', properties={}), target=Node(id='Narsaq', type='Location', properties={}), type='TRANSLATOR', properties={}), Relationship(source=Node(id='Paul Cohen', type='Person', properties={}), target=Node(id='Narsaq', type='Location', properties={}), type='PROPERTY_BUSINESS_OWNER', properties={}), Relationship(source=Node(id='Paul Cohen', type='Person', properties={}), target=Node(id='Monika', type='Person', properties={}), type='SPOUSE', properties={}), Relationship(source=Node(id='Monika', type='Per ...
#  GraphDocument(nodes=[Node(id='Greenland', type='Colony', properties={}), Node(id='Danish Colony', type='Colony', properties={}), Node(id='North Greenland', type='Region', properties={}), Node(id='South Greenland', type='Region', properties={}), Node(id='Kingdom Of Denmark', type='Kingdom', properties={}), Node(id='Governor', type='Position', properties={}), Node(id='County Of Greenland', type='County', properties={}), Node(id='Rigsdel', type='Autonomous territory', properties={})], relationships=[Relationship(source=Node(id='Greenland', type='Colony', properties={}), target=Node(id='Danish Colony', type='Colony', properties={}), type='PART_OF', properties={}), Relationship(source=Node(id='Greenland', type='Colony', properties={}), target=Node(id='North Greenland', type='Region', properties={}), type='UNION_WITH', properties={}), Relationship(source=Node(id='Greenland', type='Colony', properties={}), target=Node(id='South Greenland', type='Region', properties={}), type='UNION_WITH', properties={}), Relationship(source=Node(id='Greenland', type='Colony', properties={}), target=Node(id='Governor', type='Position', properties={}), type='RULED_BY', properties={}), Relationship(source=Node(id='Greenland', type='Colony', properties={}), target=Node(id='Kingdom Of Denmark', type='Kingdom', properties={}), type='BECAME_PART_OF', properties={}), Relationship(source=Node(id='Greenland', type='Colony', properties={}), target=Node(id='County Of Greenland', type='County', properties={}), type='BECAME', properties={}), Relationship(source=Node(id='County Of Greenland', type='County', properties={}), target=Node(id='Kingdom Of Denmark', type='Kingdom', properties={}), type='BECAME_PART_OF', properties={}), Relationship(source=Node(id='Greenland', type='Colony', properties={}), target=Node(id='Rigsdel', type='Autonomous territory', properties={}), type='BECAME', properties={})], source=Document(metadata={'title': 'Colony of Greenland', 'summary': 'The colony of Greenland was a Danish colony created in 1950 with the union of North Greenland and South Greenland, and was ruled by one governor. In 1953, the colony of Greenland was made an integral and equal part of the Kingdom of Denmark as an amt, henceforth known as the County of Greenland up until July 1979. On 1 July 1979, Greenland became a rigsdel (an autonomous territory) within the Kingdom of Denmark.', 'source': 'https://en.wikipedia.org/wiki/Colony_of_Greenland'}, page_content='The colony of Greenland was a Danish colony created in 1950 with the union of North Greenland and South Greenland, and was ruled by one governor. In 1953, the colony of Greenland was made an integral and equal part of the Kingdom of Denmark as an amt, henceforth known as the County of Greenland up until July 1979. On 1 July 1979, Greenland became a rigsdel (an autonomous territory) within the Kingdom of Denmark.\n\n\n== References ==')),
#  GraphDocument(nodes=[Node(id='Greenland', type='Territory', properties={}), Node(id='Kingdom Of Denmark', type='Country', properties={}), Node(id='Government Of Greenland', type='Government', properties={}), Node(id='Hans Egede', type='Person', properties={}), Node(id='Danish-Norwegian Missionary', type='Person', properties={}), Node(id='Navy Flyvevæsen', type='Organization', properties={}), Node(id='Geodætisk Institut', type='Organization', properties={}), Node(id='Danish Navy', type='Organization', properties={}), Node(id='Second World War', type='Event', properties={}), Node(id='Nazi Germany', type='Country', properties={}), Node(id='United States', type='Country', properties={})], relationships=[Relationship(source=Node(id='Greenland', type='Territory', properties={}), target=Node(id='Kingdom Of Denmark', type='Country', properties={}), type='RESPONSIBLE_FOR_DEFENCE', properties={}), Relationship(source=Node(id='Government Of Greenland', type='Government', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='NO_CONTROL_OVER_MILITARY_AFFAIRS', properties={}), Relationship(source=Node(id='Government Of Greenland', type='Government', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='NO_CONTROL_OVER_FOREIGN_AFFAIRS', properties={}), Relationship(source=Node(id='Hans Egede', type='Person', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='FIRST_COLONIZER', properties={}), Relationship(source=Node(id='Danish-Norwegian Missionary', type='Person', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='FIRST_COLONIZER', properties={}), Relationship(source=Node(id='Navy Flyvevæsen', type='Organization', properties={}), target=Node(id='Geodætisk Institut', type='Organization', properties={}), type='CONTRIBUTED_AERIAL_PHOTOGRAPHY', properties={}), Relationship(source=Node(id='Danish Navy', type='Organization', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='EXPLORED_GREENLAND', properties={}), Relationship(source=Node(id='Danish Navy', type='Organization', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='SURVEYED_AND_CARTOGRAPHY', properties={}), Relationship(source=Node(id='Greenland', type='Territory', properties={}), target=Node(id='Kingdom Of Denmark', type='Country', properties={}), type='GAINED_REPRESENTATION_IN_PARLIAMENT', properties={}), Relationship(source=Node(id='Kingdom Of Denmark', type='Country', properties={}), target=Node(id='United States', type='Country', properties={}), type='AGREEMENT_SIGNED', properties={}), Relationship(source=Node(id='Kingdom Of Denmark', type='Country', properties={}), target=Node(id='Nazi Germany', type='Country', properties={}), type='OCCUPIED_BY', properties={}), Relationship(source=Node(id='Greenland', type='Territory', properties={}), target=Node(id='United States', type='Country', properties={}), type='ASSISTED_TO_MAINTAIN_NON_GERMAN_STATUS', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='BUILT_AIRFIELDS_AND_HARBORS', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='BUILT_ANTI_AIRCRAFT_FORTIFICATIONS', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='BUILT_RADIO_AND_METEOROLOGICAL_SITES', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='Greenland', type='Territory', properties={}), type='FEARED_GERMAN_USE_AS_BASE', properties={})], source=Document(metadata={'title': 'Military in Greenland', 'summary': "The defence of Greenland is the responsibility of the Kingdom of Denmark; the government of Greenlan ...
# ...
#  GraphDocument(nodes=[Node(id='Aalborg', type='Airfield', properties={}), Node(id='Norway', type='Country', properties={}), Node(id='Denmark', type='Country', properties={}), Node(id='Adolf Hitler', type='Person', properties={}), Node(id='South Jutland', type='Territory', properties={}), Node(id='German Minority', type='Ethnic group', properties={}), Node(id='Versailles Treaty', type='Treaty', properties={}), Node(id='Nordic Union', type='Union', properties={}), Node(id='Anglo-French Attacks', type='Conflict', properties={}), Node(id='German Forces', type='Military', properties={}), Node(id='German Ships', type='Military', properties={}), Node(id='Copenhagen', type='City', properties={}), Node(id='Danish Soldiers', type='Military', properties={}), Node(id='Royal Guard', type='Military', properties={}), Node(id='Oprop! Leaflets', type='Document', properties={})], relationships=[Relationship(source=Node(id='Aalborg', type='Airfield', properties={}), target=Node(id='Norway', type='Country', properties={}), type='OPERATION_LOCATION', properties={}), Relationship(source=Node(id='Aalborg', type='Airfield', properties={}), target=Node(id='Denmark', type='Country', properties={}), type='OPERATION_LOCATION', properties={}), Relationship(source=Node(id='Adolf Hitler', type='Person', properties={}), target=Node(id='Denmark', type='Country', properties={}), type='DECISION_MAKER', properties={}), Relationship(source=Node(id='Germany', type='Country', properties={}), target=Node(id='South Jutland', type='Territory', properties={}), type='TERRITORIAL_DISPUTE', properties={}), Relationship(source=Node(id='South Jutland', type='Territory', properties={}), target=Node(id='German Minority', type='Ethnic group', properties={}), type='RESIDENT', properties={}), Relationship(source=Node(id='South Jutland', type='Territory', properties={}), target=Node(id='Versailles Treaty', type='Treaty', properties={}), type='HISTORICAL_EVENT', properties={}), Relationship(source=Node(id='Germany', type='Country', properties={}), target=Node(id='Nordic Union', type='Union', properties={}), type='INTEGRATION_PLAN', properties={}), Relationship(source=Node(id='Germany', type='Country', properties={}), target=Node(id='Denmark', type='Country', properties={}), type='PROTECTORATE_CLAIM', properties={}), Relationship(source=Node(id='Germany', type='Country', properties={}), target=Node(id='Anglo-French Attacks', type='Conflict', properties={}), type='REASONING', properties={}), Relationship(source=Node(id='German Forces', type='Military', properties={}), target=Node(id='Denmark', type='Country', properties={}), type='INVASION', properties={}), Relationship(source=Node(id='German Ships', type='Military', properties={}), target=Node(id='Copenhagen', type='City', properties={}), type='TROOP_DISEMBARKATION', properties={}), Relationship(source=Node(id='Danish Soldiers', type='Military', properties={}), target=Node(id='Denmark', type='Country', properties={}), type='RESISTANCE', properties={}), Relationship(source=Node(id='Royal Guard', type='Military', properties={}), target=Node(id='Copenhagen', type='City', properties={}), type='RESISTANCE', properties={}), Relationship(source=Node(id='Danish Soldiers', type='Military', properties={}), target=Node(id='South Jutland', type='Territory', properties={}), type='RESISTANCE', properties={}), Relationship(source=Node(id='German Forces', type='Military', properties={}), target=Node(id='Copenhagen', type='City', properties={}), type='LEAFLET_DROP', properties={}), Relationship(source=Node(id='Oprop! Leaflets', type='Document', properties={}), target=Node(id='Copenhagen', type='City', properties={}), type='PROPAGANDA', properties={})], source=Document(metadata={'title': 'Denmark in World War II', 'summary': 'At the outset of World War II in September 1939, Denmark declared itself neutral, but that neutrality did not prevent Nazi Germany from occupying the country soon after the outbreak of war; the occupation lasted until Germany\' ...
#  GraphDocument(nodes=[Node(id='Denmark', type='Country', properties={}), Node(id='Israel', type='Country', properties={}), Node(id='World Zionist Organization', type='Organization', properties={}), Node(id='Copenhagen', type='City', properties={}), Node(id='Paris Peace Conference', type='Event', properties={}), Node(id='Danish Jewish Community', type='Community', properties={}), Node(id='Sweden', type='Country', properties={}), Node(id='Righteous Among Nations', type='Title', properties={}), Node(id='Danish Resistance Movement', type='Organization', properties={}), Node(id='Jerusalem', type='City', properties={}), Node(id='Haifa', type='City', properties={}), Node(id='Denya Square', type='Monument', properties={}), Node(id='King Christian X Hospital', type='Hospital', properties={}), Node(id='Eitanim', type='City', properties={}), Node(id='Stone At Israels Plads', type='Monument', properties={}), Node(id='Ryvangen Memorial Park', type='Park', properties={}), Node(id='Hellerup', type='City', properties={}), Node(id='Gilleleje', type='City', properties={}), Node(id='Køge', type='City', properties={}), Node(id='United Nations', type='Organization', properties={}), Node(id='Embassy', type='Building', properties={}), Node(id='Partition Of Palestine', type='Event', properties={}), Node(id='Kibbutz', type='Community', properties={}), Node(id='Anders Fogh Rasmussen', type='Person', properties={})], relationships=[Relationship(source=Node(id='Denmark', type='Country', properties={}), target=Node(id='Israel', type='Country', properties={}), type='BILATERAL_RELATION', properties={}), Relationship(source=Node(id='World Zionist Organization', type='Organization', properties={}), target=Node(id='Copenhagen', type='City', properties={}), type='SET_UP_OFFICE', properties={}), Relationship(source=Node(id='World Zionist Organization', type='Organization', properties={}), target=Node(id='Paris Peace Conference', type='Event', properties={}), type='PRESENT_CLAIMS', properties={}), Relationship(source=Node(id='Danish Jewish Community', type='Community', properties={}), target=Node(id='Sweden', type='Country', properties={}), type='RESCUED_JEWS', properties={}), Relationship(source=Node(id='Danish Resistance Movement', type='Organization', properties={}), target=Node(id='Righteous Among Nations', type='Title', properties={}), type='RECEIVED_HONORIFIC_TITLE', properties={}), Relationship(source=Node(id='Jerusalem', type='City', properties={}), target=Node(id='Denya Square', type='Monument', properties={}), type='SCULPTURE_MONUMENT', properties={}), Relationship(source=Node(id='Haifa', type='City', properties={}), target=Node(id='Denya Square', type='Monument', properties={}), type='SCULPTURE_MONUMENT', properties={}), Relationship(source=Node(id='Jerusalem', type='City', properties={}), target=Node(id='Denmark', type='Country', properties={}), type='SCHOOL_NAMED', properties={}), Relationship(source=Node(id='King Christian X Hospital', type='Hospital', properties={}), target=Node(id='Eitanim', type='City', properties={}), type='NAMED_AFTER', properties={}), Relationship(source=Node(id='Copenhagen', type='City', properties={}), target=Node(id='Stone At Israels Plads', type='Monument', properties={}), type='MAIN_MONUMENT', properties={}), Relationship(source=Node(id='Ryvangen Memorial Park', type='Park', properties={}), target=Node(id='Hellerup', type='City', properties={}), type='REFERENCES_UNDERGROUND_MEMBERS', properties={}), Relationship(source=Node(id='Gilleleje', type='City', properties={}), target=Node(id='Sweden', type='Country', properties={}), type='SENT_JEWS', properties={}), Relationship(source=Node(id='Køge', type='City', properties={}), target=Node(id='Sweden', type='Country', properties={}), type='SENT_JEWS', properties={}), Relationship(source=Node(id='Denmark', type='Country', properties={}), target=Node(id='Partition Of Palestine', type='Event', properties={}), type='VOTED_FOR', properties={}), Relationship(source=Node(id='Denmark',  ...
#  GraphDocument(nodes=[Node(id='Denmark', type='Country', properties={}), Node(id='Yad Vashem', type='Organization', properties={}), Node(id='Danish Jews', type='Group', properties={}), Node(id='Nazi Concentration Camps', type='Location', properties={}), Node(id='Copenhagen', type='City', properties={}), Node(id='Aarhus', type='City', properties={}), Node(id='Odense', type='City', properties={}), Node(id='Israeli Embassy', type='Location', properties={}), Node(id='Israel', type='Country', properties={}), Node(id='Michael Melchior', type='Person', properties={}), Node(id='Bent Melchior', type='Person', properties={}), Node(id='Arne Melchior', type='Person', properties={}), Node(id='Marcus Melchior', type='Person', properties={}), Node(id='Ron Pundak', type='Person', properties={}), Node(id='Peres Center For Peace', type='Organization', properties={}), Node(id='Oslo Peace Process', type='Event', properties={}), Node(id='Geneva Initiative', type='Event', properties={}), Node(id='Herbert Pundik', type='Person', properties={}), Node(id='Yohanan Plesner', type='Person', properties={}), Node(id='Plesner Committee', type='Organization', properties={}), Node(id='Ulrik Plesner', type='Person', properties={}), Node(id='Viggo Kampmann', type='Person', properties={}), Node(id='David Ben-Gurion', type='Person', properties={}), Node(id='Mordechai Ish', type='Person', properties={})], relationships=[Relationship(source=Node(id='Denmark', type='Country', properties={}), target=Node(id='Yad Vashem', type='Organization', properties={}), type='RECOGNIZED_FOR_RESCUE_OF_DANISH_JEWS_DURING_WWII', properties={}), Relationship(source=Node(id='Denmark', type='Country', properties={}), target=Node(id='Nazi Concentration Camps', type='Location', properties={}), type='APOLOGIZED_FOR_SENDING_JEWS_TO_NAZI_CONCENTRATION_CAMPS', properties={}), Relationship(source=Node(id='Copenhagen', type='City', properties={}), target=Node(id='Israeli Embassy', type='Location', properties={}), type='PROTESTS_IN_FRONT_OF_ISRAELI_EMBASSY', properties={}), Relationship(source=Node(id='Aarhus', type='City', properties={}), target=Node(id='Israeli Embassy', type='Location', properties={}), type='PROTESTS_IN_FRONT_OF_ISRAELI_EMBASSY', properties={}), Relationship(source=Node(id='Odense', type='City', properties={}), target=Node(id='Israeli Embassy', type='Location', properties={}), type='PROTESTS_IN_FRONT_OF_ISRAELI_EMBASSY', properties={}), Relationship(source=Node(id='Michael Melchior', type='Person', properties={}), target=Node(id='Bent Melchior', type='Person', properties={}), type='FAMILY_RELATION', properties={}), Relationship(source=Node(id='Michael Melchior', type='Person', properties={}), target=Node(id='Arne Melchior', type='Person', properties={}), type='FAMILY_RELATION', properties={}), Relationship(source=Node(id='Michael Melchior', type='Person', properties={}), target=Node(id='Marcus Melchior', type='Person', properties={}), type='FAMILY_RELATION', properties={}), Relationship(source=Node(id='Ron Pundak', type='Person', properties={}), target=Node(id='Herbert Pundik', type='Person', properties={}), type='FAMILY_RELATION', properties={}), Relationship(source=Node(id='Ron Pundak', type='Person', properties={}), target=Node(id='Oslo Peace Process', type='Event', properties={}), type='CONTRIBUTED_TO_STARTING_OSLO_PEACE_PROCESS', properties={}), Relationship(source=Node(id='Ron Pundak', type='Person', properties={}), target=Node(id='Geneva Initiative', type='Event', properties={}), type='PART_OF_CORE_GROUP_BEHIND_GENEVA_INITIATIVE', properties={}), Relationship(source=Node(id='Yohanan Plesner', type='Person', properties={}), target=Node(id='Ulrik Plesner', type='Person', properties={}), type='FAMILY_RELATION', properties={}), Relationship(source=Node(id='Viggo Kampmann', type='Person', properties={}), target=Node(id='Israel', type='Country', properties={}), type='FIRST_SENIOR_FIGURE_FROM_DENMARK_TO_VISIT_ISRAEL', properties={})], source=Document(metadata={'title': 'Denm ...

# %%
graph.add_graph_documents(
    graph_documents,
    baseEntityLabel=True,
    include_source=True
)

# %%
# directly show the graph resulting from the given Cypher query
default_cypher = "MATCH (s)-[r:!MENTIONS]->(t) RETURN s,r,t LIMIT 50"

# %%
from yfiles_jupyter_graphs import GraphWidget
from neo4j import GraphDatabase

# %%
try:
  import google.colab
  from google.colab import output
  output.enable_custom_widget_manager()
except:
  pass

# %%
def showGraph(cypher: str = default_cypher):
    # create a neo4j session to run queries
    driver = GraphDatabase.driver(
        uri = os.environ["NEO4J_URI"],
        auth = (os.environ["NEO4J_USERNAME"],
                os.environ["NEO4J_PASSWORD"]))
    session = driver.session()
    widget = GraphWidget(graph = session.run(cypher).graph())
    widget.node_label_mapping = 'id'
    display(widget)
    return widget

# %%
showGraph()
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %%
from typing import Tuple, List, Optional

# %%
from langchain_community.vectorstores import Neo4jVector

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts.prompt import PromptTemplate

# %%
from langchain_openai import OpenAIEmbeddings
vector_index = Neo4jVector.from_existing_graph(
    OpenAIEmbeddings(),
    search_type="hybrid",
    node_label="Document",
    text_node_properties=["text"],
    embedding_node_property="embedding"
)

# %%
graph.query("CREATE FULLTEXT INDEX entity IF NOT EXISTS FOR (e:__Entity__) ON EACH [e.id]")
# Out:
# []

# %%
from pydantic import BaseModel, Field
from typing import List

# Extract entities from text
class Entities(BaseModel):
    """Identifying information about entities."""
    names: List[str] = Field(
        ...,
        description="All the person, organization, or business entities that "
        "appear in the text",
    )

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are extracting organization and person entities from the text.",
        ),
        (
            "human",
            "Use the given format to extract information from the following "
            "input: {question}",
        ),
    ]
)

# %%
entity_chain = prompt | llm.with_structured_output(Entities)
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_openai/chat_models/base.py:2073: UserWarning: Cannot use method='json_schema' with model gpt-3.5-turbo-0125 since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(

# %%
entity_chain.invoke({"question": "Who is Erik the Red?"}).names
# Out:
# ['Erik the Red']

# %%
from langchain_neo4j.vectorstores.neo4j_vector import remove_lucene_chars

# %%
def generate_full_text_query(input: str) -> str:
    full_text_query = ""
    words = [el for el in remove_lucene_chars(input).split() if el]
    for word in words[:-1]:
        full_text_query += f" {word}~2 AND"
    full_text_query += f" {words[-1]}~2"
    return full_text_query.strip()

# %%
def structured_retriever(question: str) -> str:
    result = ""
    entities = entity_chain.invoke({"question": question})
    for entity in entities.names:
        response = graph.query(
            """CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})
            YIELD node,score
            CALL (node) {
              MATCH (node)-[r:!MENTIONS]->(neighbor)
              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output
              UNION ALL
              MATCH (node)<-[r:!MENTIONS]-(neighbor)
              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output
            }
            RETURN output LIMIT 50
            """,
            {"query": generate_full_text_query(entity)},
        )
        result += "\n".join([el['output'] for el in response])
    return result

# %%
print(structured_retriever("Who is Erik the Red?"))
# Out:
# Erik The Red - DISCOVERY -> Greenland
# Erik The Red - SETTLEMENT -> Greenland
# Saga Of Erik The Red - ABOUT -> Grænlendingar

# %%
def retriever(question: str):
    print(f"Search query: {question}")
    structured_data = structured_retriever(question)
    unstructured_data = [el.page_content for el in vector_index.similarity_search(question)]
    final_data = f"""Structured data:
{structured_data}
Unstructured data:
{"#Document ". join(unstructured_data)}
    """
    return final_data

# %%
_template = """Given the following conversation and a follow up question, rephrase the follow up question to be a standalone question,
in its original language.
Chat History:
{chat_history}
Follow Up Input: {question}
Standalone question:"""

# %%
CONDENSE_QUESTION_PROMPT = PromptTemplate.from_template(_template)

# %%
from langchain_core.runnables import (
    RunnableBranch,
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)

# %%
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.output_parsers import StrOutputParser

# %%
def _format_chat_history(chat_history: List[Tuple[str, str]]) -> List:
    buffer = []
    for human, ai in chat_history:
        buffer.append(HumanMessage(content=human))
        buffer.append(AIMessage(content=ai))
    return buffer

# %%
_search_query = RunnableBranch(
    # If input includes chat_history, we condense it with the follow-up question
    (
        RunnableLambda(lambda x: bool(x.get("chat_history"))).with_config(
            run_name="HasChatHistoryCheck"
        ),  # Condense follow-up question and chat into a standalone_question
        RunnablePassthrough.assign(
            chat_history=lambda x: _format_chat_history(x["chat_history"])
        )
        | CONDENSE_QUESTION_PROMPT
        | ChatOpenAI(temperature=0)
        | StrOutputParser(),
    ),
    # Else, we have no chat history, so just pass through the question
    RunnableLambda(lambda x : x["question"]),
)

# %%
template = """Answer the question based only on the following context:
{context}

Question: {question}
Use natural language and be concise.
Answer:"""

# %%
prompt = ChatPromptTemplate.from_template(template)

# %%
chain = (
    RunnableParallel(
        {
            "context": _search_query | retriever,
            "question": RunnablePassthrough(),
        }
    )
    | prompt
    | llm
    | StrOutputParser()
)

# %%
import logging
logging.getLogger("neo4j").setLevel(logging.ERROR)
logging.getLogger("neo4j.notifications").setLevel(logging.ERROR)

# %%
chain.invoke({"question": "Which house did Frederick IV of Denmark belong to?"})
# Out:
# Search query: Which house did Frederick IV of Denmark belong to?
# 'Frederick IV of Denmark belonged to the House of Oldenburg.'

# %%
chain.invoke({"question": "When did the Western Settlement disappear?"})
# Out:
# Search query: When did the Western Settlement disappear?
# 'The Western Settlement in Greenland disappeared around the year 1355.'

# %%
chain.invoke({"question": "What happened during World War II in Greenland?"})
# Out:
# Search query: What happened during World War II in Greenland?
# 'During World War II, Greenland declared itself a self-ruling territory after Denmark was occupied by Nazi Germany. The United States established facilities for air and sea traffic, leading to economic growth through trade with the US, Canada, and Portugal. Greenland also played a strategic role in the Allied war efforts, with the US building military bases and maintaining control over the territory.'

# %%
chain.invoke({"question": "What did the Norse trade from Greenland?"})
# Out:
# Search query: What did the Norse trade from Greenland?
# 'The Norse settlers in Greenland traded with the Dutch for opportunities in trade and a new life in America.'

# %%
chain.invoke({"question": "Which dual-state entity claimed sovereignty over Greenland in 1721?"})
# Out:
# Search query: Which dual-state entity claimed sovereignty over Greenland in 1721?
# 'Denmark-Norway claimed sovereignty over Greenland in 1721.'

# %%
chain.invoke({"question": "Which Norwegian archdiocese was the Diocese of Garðar subject to?"})
# Out:
# Search query: Which Norwegian archdiocese was the Diocese of Garðar subject to?
# 'The Diocese of Garðar was subject to the Archbishop of Lund.'

# %%
chain.invoke({"question": "Who discovered Greenland and where were they from?"})
# Out:
# Search query: Who discovered Greenland and where were they from?
# 'Greenland was discovered by Norse Icelandic explorers who settled on its southwestern coast in the 9th century CE.'

# %%
chain.invoke({"question": "Why is Greenland Danish instead of Norwegian?"})
# Out:
# Search query: Why is Greenland Danish instead of Norwegian?
# 'Greenland is Danish instead of Norwegian because it has been politically and culturally associated with the European kingdoms of Norway and Denmark for over a millennium, beginning in 986. Greenland was transferred from the Norwegian to the Danish crown in 1814 when Denmark and Norway separated. Greenland has been under Danish sovereignty since then.'

# %%
chain.invoke({"question": "What historical connections exist between Norway, Denmark, and Greenland?"})
# Out:
# Search query: What historical connections exist between Norway, Denmark, and Greenland?
# 'Norway and Denmark were part of a historical union called Denmark-Norway, which included Greenland as a colony. Greenland was initially under Norwegian rule, then became part of the Kalmar Union with Denmark and Sweden, and later fell under Danish control as part of Denmark-Norway.'
